# %%
library(gtsummary)
# Out:
# #Uighur

# %%
df <- read.table("data/processed/dataset_processed.tsv", sep="\t", header=T, row.names="Code.ID")
df <- df[df$Amyloid_type=='AL',]
df <- df[df$Kappa_or_lambda_PCD %in% c("L","K"),]

# %%
colnames(df)
# Out:
#  [1] "Date_of_admission_to_center"
#  [2] "Date_of_birth"
#  [3] "Date_of_diagnosis"
#  [4] "Date_of_death"
#  [5] "Date_of_last_visit"
#  [6] "Cardiopulmonary_symptom_onset"
#  [7] "Renal_signs_symptom_onset"
#  [8] "Neurologic_symptom_onset"
#  [9] "Amyloid_type"
# [10] "Age"
# [11] "Time_to_death_from_diagnosis__m_"
# [12] "Sex"
# [13] "Ethnicity"
# [14] "Race"
# [15] "Education"
# [16] "Abdominal_fat_pad_CR_staining"
# [17] "Bone_marrow_CR_staining"
# [18] "Kappa_or_lambda_PCD"
# [19] "Kappa_sFLC"
# [20] "Lambda_sFLC"
# [21] "kappa_lambda_ratio"
# [22] "dFLC"
# [23] "Heart"
# [24] "Kidney"
# [25] "Liver"
# [26] "GI_Tract"
# [27] "Lung"
# [28] "Neurologic"
# [29] "X_Autonomic_"
# [30] "X_Peripheral_"
# [31] "Soft_tissue_MSK"
# [32] "Dermatologic"
# [33] "Primary_organ"
# [34] "Secondary_organ"
# [35] "Weight_loss"
# [36] "Fatigue"
# [37] "Exertional_dyspnea"
# [38] "Dyspnea_at_rest"
# [39] "Orthopnea_PND"
# [40] "Leg_swelling__symptom_"
# [41] "Peripheral_edema_on_exam"
# ...

# %%
df %>% 
    tbl_summary(
        include = c(Age, Sex, Kappa_or_lambda_PCD, dFLC, Bone_marrow_plasma_cells____),
        label = list(
            Kappa_or_lambda_PCD ~ "LC Isotype",
            Bone_marrow_plasma_cells____ ~ "BMPC, %"
        )
    ) %>%
    as_gt() %>% gt::gtsave(filename='test.pdf')

# %%
df %>% 
    tbl_summary(include = c(
    
    
    
    )) %>%
    as_gt() %>% gt::gtsave(filename='test.pdf')

# %%
table1 <- 
  trial %>%
  tbl_summary(include = c(age, grade, response)) %>% as_gt() %>% gt::gtsave(filename='test.pdf')

# %%
table1
# Out:
# <div id="lcbmycdxue" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>#lcbmycdxue table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #lcbmycdxue thead, #lcbmycdxue tbody, #lcbmycdxue tfoot, #lcbmycdxue tr, #lcbmycdxue td, #lcbmycdxue th {
#   border-style: none;
# }
#
# #lcbmycdxue p {
#   margin: 0;
#   padding: 0;
# }
#
# #lcbmycdxue .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
# ...

# %%
trial2 %>% tbl_summary()
# Out:
# <div id="ehtmcvfiwq" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>#ehtmcvfiwq table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #ehtmcvfiwq thead, #ehtmcvfiwq tbody, #ehtmcvfiwq tfoot, #ehtmcvfiwq tr, #ehtmcvfiwq td, #ehtmcvfiwq th {
#   border-style: none;
# }
#
# #ehtmcvfiwq p {
#   margin: 0;
#   padding: 0;
# }
#
# #ehtmcvfiwq .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
# ...
